# %%
import numpy as np
import matplotlib.pyplot as plt
from typing import Callable, Union

# include the path to the src. module
import sys
sys.path.append('../src')

from algebraic import VectorSpace, AffineSpace
from elements import Vector as V, Field as F

fig = plt.figure()
ax = plt.axes(projection='3d')

ax.view_init(elev=30, azim=60)

VS = VectorSpace(F({0, 1, 2, 3}, [lambda x, y: (x + y) % 4, lambda x, y: (x * y) % 4]), [V(1, 2, 0), V(0, 1, 4)])
A = AffineSpace(VS, [20, 10, 15])

x, y = np.linspace(-6, 6, 30), np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = (A.parametricEquation())([X, Y])

ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none', alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\jansa\source\repos\AGLibrary\aglibrary\tests\Note.ipynb Cell 1' in <cell line: 17>()
#      <a href='vscode-notebook-cell:/c%3A/Users/jansa/source/repos/AGLibrary/aglibrary/tests/Note.ipynb#ch0000000?line=12'>13</a> ax = plt.axes(projection='3d')
#      <a href='vscode-notebook-cell:/c%3A/Users/jansa/source/repos/AGLibrary/aglibrary/tests/Note.ipynb#ch0000000?line=14'>15</a> ax.view_init(elev=30, azim=60)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/jansa/source/repos/AGLibrary/aglibrary/tests/Note.ipynb#ch0000000?line=16'>17</a> VS = VectorSpace(F({0, 1, 2, 3}, {lambda x, y: (x + y) % 4, lambda x, y: (x * y) % 4}), [V(1, 2, 0), V(0, 1, 4)])
#      <a href='vscode-notebook-cell:/c%3A/Users/jansa/source/repos/AGLibrary/aglibrary/tests/Note.ipynb#ch0000000?line=17'>18</a> A = AffineSpace(VS, [20, 10, 15])
#      <a href='vscode-notebook-cell:/c%3A/Users/jansa/source/repos/AGLibrary/aglibrary/tests/Note.ipynb#ch0000000?line=19'>20</a> x, y = np.linspace(-6, 6, 30), np.linspace(-6, 6, 30)
#
# File c:\Users\jansa\source\repos\AGLibrary\aglibrary\tests\../src\elements.py:485, in Field.__init__(self, elements, operations)
#     <a href='file:///c%3A/Users/jansa/source/repos/AGLibrary/aglibrary/tests/../src/elements.py?line=479'>480</a> def __init__(self, elements: set[T], operations: list[Callable[[T, T], T]]):
#     <a href='file:///c%3A/Users/jansa/source/repos/AGLibrary/aglibrary/tests/../src/elements.py?line=480'>481</a>     """
#     <a href='file:///c%3A/Users/jansa/source/repos/AGLibrary/aglibrary/tests/../src/elements.py?line=481'>482</a>     :param elements: A set of elements
#     <a href='file:///c%3A/Users/jansa/source/repos/AGLibrary/aglibrary/tests/../src/elements.py?line=482'>483</a>     :param operations: A set of binary operations that are associative and commutative
#     <a href='file:///c%3A/Users/jansa/source/repos/AGLibrary/aglibrary/tests/../src/elements.py?line=483'>484</a>     """
# --> <a href='file:///c%3A/Users/jansa/source/repos/AGLibrary/aglibrary/tests/../src/elements.py?line=484'>485</a>     super().__init__(elements, operations)
#     <a href='file:///c%3A/Users/jansa/source/repos/AGLibrary/aglibrary/tests/../src/elements.py?line=485'>486</a>     self.identities.add(lambda x, y: self.operations[1](x, y) == self.operations[1](y, x))
#     <a href='file:///c%3A/Users/jansa/source/repos/AGLibrary/aglibrary/tests/../src/elements.py?line=486'>487</a>     self.identities.add(Inverse.__call__(self.operations[1]))
#
# File c:\Users\jansa\source\repos\AGLibrary\aglibrary\tests\../src\elements.py:365, in Ring.__init__(self, elements, operations)
#     <a href='file:///c%3A/Users/jansa/source/repos/AGLibrary/aglibrary/tests/../src/elements.py?line=361'>362</a> if (len(operations) != 2):
#     <a href='file:///c%3A/Users/jansa/source/repos/AGLibrary/aglibrary/tests/../src/elements.py?line=362'>363</a>     raise ValueError("The ring must have two operations")
#     <a href='file:///c%3A/Users/jansa/source/repos/AGLibrary/aglibrary/tests/../src/elements.py?line=363'>364</a> super().__init__(elements, operations,
# --> <a href='file:///c%3A/Users/jansa/source/repos/AGLibrary/aglibrary/tests/../src/elements.py?line=364'>365</a> Group(elements, operations[0]).abelian().get_identities() | Monoid(elements, operations[1]).get_identities() |
#     <a href='file:///c%3A/Users/jansa/source/repos/AGLibrary/aglibrary/tests/../src/elements.py?line=365'>366</a> {lambda x, y: Commutative.__call__(self.operations[0](x, y), self.operations[1])})
#
# TypeError: 'set' object is not subscriptable

# %%
import numpy as np
import matplotlib.pyplot as plt
from typing import Callable, Union

# include the path to the src. module
import sys
sys.path.append('../src')

from algebraic import VectorSpace, AffineSpace
from elements import Vector

fig = plt.figure()
ax = plt.axes()

#ax.view_init(elev=30, azim=60)

V = VectorSpace({0, 1, 2}, [[1, 2, 0], [0, 1, 4]])
A = AffineSpace(V, [20, 10, 15])

x, y = np.linspace(-12, 12, 30), np.linspace(-10, 10, 30)

X, Y = np.meshgrid(x, y)
#Y = (A.parametricEquation())([X])

ax.plot()
ax.contour(X, Y, X*X + Y*Y + 4*X*Y + X**3 -22, [0], edgecolor='none')

#ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
#                cmap='viridis', edgecolor='none', alpha=0.5)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from typing import Callable, Union

# include the path to the src. module
import sys
sys.path.append('../src')

from algebraic import VectorSpace, AffineSpace, AffineVariety
from elements import Vector

fig = plt.figure()
ax = plt.axes(projection='3d')

#ax.view_init(elev=30, azim=60)

V = VectorSpace({0, 1, 2}, [[1, 2, 0], [0, 1, 4]])
A = AffineSpace(V, [20, 10, 15])
AV = AffineVariety(A, [lambda x, y: x*x + y*y - 4, lambda x, y: x**3 - 4*x*y])

X = np.linspace(-3, 3, 30)
Y = np.linspace(-3, 3, 30)
X, Y = np.meshgrid(X, Y)
#Y = (A.parametricEquation())([X])

#ax.plot_surface(X, Y, X*X - Y*Y, rstride=1, cstride=1, cmap = cm.viridis, antialiased=False, alpha = 0.5)
ax.contour(X, Y, AV.equations[0](X, Y), zdir='z', offset=0, levels = [0])
ax.contour(X, Y, AV.equations[1](X, Y), zdir='z', offset=0, levels = [0], colors = 'red')
#ax.contour(X, Y, X*X, zdir='z', offset=-2, levels = [0])
#ax.contour(X, Y, X*X - Y*Y, levels = [0])
ax.set_zlim(zmin = -2)
#AV.equations[0](X, Y) - AV.equations[1](X, Y)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from typing import Callable, Union

# include the path to the src. module
import sys
sys.path.append('../src')

from algebraic import VectorSpace, AffineSpace, AffineVariety, Monomial
from elements import Vector

f = Monomial({0, 1, 2}, [1, 3, 2], 1)

fig = plt.figure()
ax = plt.axes()

f.plot2d([-5, 5], [-5, 5])
