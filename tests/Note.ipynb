# %%
import numpy as np
import matplotlib.pyplot as plt
from typing import Callable, Union

# include the path to the src. module
import sys
sys.path.append('../src')

from algebraic import VectorSpace, AffineSpace
from elements import Vector as V, Field as F, Group as G, Module as M

fig = plt.figure()
ax = plt.axes(projection='3d')

ax.view_init(elev=30, azim=60)

base = [V(1, 2, 0), V(0, 1, 4)]

# Vector space with modulo 4 field and vectors with the modulo 5 group defined by vector addition
F4 = F({0, 1, 2, 3}, [lambda x, y: (x + y) % 4, lambda x, y: (x * y) % 4])
G5 = G({V(1, 2, 0), V(0, 1, 4)}, lambda u, v: (u + v) % 5).abelian()

FM5 = M(F4, G5, lambda a, v: (a * v) % 5)

VS = VectorSpace(FM5, base)
AS = AffineSpace(VS, V(200, 100, 150))

x, y = np.linspace(-6, 6, 30), np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = (VS.parametricEquation())([X, Y])

ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none', alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\jansa\source\repos\AGLibrary\aglibrary\tests\Note.ipynb Cell 1' in <cell line: 31>()
#      <a href='vscode-notebook-cell:/c%3A/Users/jansa/source/repos/AGLibrary/aglibrary/tests/Note.ipynb#ch0000000?line=27'>28</a> x, y = np.linspace(-6, 6, 30), np.linspace(-6, 6, 30)
#      <a href='vscode-notebook-cell:/c%3A/Users/jansa/source/repos/AGLibrary/aglibrary/tests/Note.ipynb#ch0000000?line=29'>30</a> X, Y = np.meshgrid(x, y)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/jansa/source/repos/AGLibrary/aglibrary/tests/Note.ipynb#ch0000000?line=30'>31</a> Z = (VS.parametricEquation())([X, Y])
#      <a href='vscode-notebook-cell:/c%3A/Users/jansa/source/repos/AGLibrary/aglibrary/tests/Note.ipynb#ch0000000?line=32'>33</a> ax.plot_surface(X, Y, np.array([X, Y]), rstride=1, cstride=1,
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from typing import Callable, Union

# include the path to the src. module
import sys
sys.path.append('../src')

from algebraic import VectorSpace, AffineSpace
from elements import Vector

fig = plt.figure()
ax = plt.axes()

#ax.view_init(elev=30, azim=60)

V = VectorSpace({0, 1, 2}, [[1, 2, 0], [0, 1, 4]])
A = AffineSpace(V, [20, 10, 15])

x, y = np.linspace(-12, 12, 30), np.linspace(-10, 10, 30)

X, Y = np.meshgrid(x, y)
#Y = (A.parametricEquation())([X])

ax.plot()
ax.contour(X, Y, X*X + Y*Y + 4*X*Y + X**3 -22, [0], edgecolor='none')

#ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
#                cmap='viridis', edgecolor='none', alpha=0.5)
# Out:
# [[[], [1, 2, 0], [1, 2, 0, 1, 2, 0]], [[], [0, 1, 4], [0, 1, 4, 0, 1, 4]]]
# [[[], []], [[], [0, 1, 4]], [[], [0, 1, 4, 0, 1, 4]], [[1, 2, 0], []], [[1, 2, 0], [0, 1, 4]], [[1, 2, 0], [0, 1, 4, 0, 1, 4]], [[1, 2, 0, 1, 2, 0], []], [[1, 2, 0, 1, 2, 0], [0, 1, 4]], [[1, 2, 0, 1, 2, 0], [0, 1, 4, 0, 1, 4]]]
# [[], [0, 1, 4], [0, 1, 4, 0, 1, 4], [1, 2, 0], [1, 2, 0, 0, 1, 4], [1, 2, 0, 0, 1, 4, 0, 1, 4], [1, 2, 0, 1, 2, 0], [1, 2, 0, 1, 2, 0, 0, 1, 4], [1, 2, 0, 1, 2, 0, 0, 1, 4, 0, 1, 4]]
# [[], [0, 1, 4], [0, 1, 4, 0, 1, 4], [1, 2, 0], [1, 2, 0, 0, 1, 4], [1, 2, 0, 0, 1, 4, 0, 1, 4], [1, 2, 0, 1, 2, 0], [1, 2, 0, 1, 2, 0, 0, 1, 4], [1, 2, 0, 1, 2, 0, 0, 1, 4, 0, 1, 4]]
# C:\Users\jansa\AppData\Local\Temp\ipykernel_21040\4131415242.py:26: UserWarning: The following kwargs were not used by contour: 'edgecolor'
#   ax.contour(X, Y, X*X + Y*Y + 4*X*Y + X**3 -22, [0], edgecolor='none')

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from typing import Callable, Union

# include the path to the src. module
import sys
sys.path.append('../src')

from algebraic import VectorSpace, AffineSpace, AffineVariety
from elements import Vector

fig = plt.figure()
ax = plt.axes(projection='3d')

#ax.view_init(elev=30, azim=60)

V = VectorSpace({0, 1, 2}, [[1, 2, 0], [0, 1, 4]])
A = AffineSpace(V, [20, 10, 15])
AV = AffineVariety(A, [lambda x, y: x*x + y*y - 4, lambda x, y: x**3 - 4*x*y])

X = np.linspace(-3, 3, 30)
Y = np.linspace(-3, 3, 30)
X, Y = np.meshgrid(X, Y)
#Y = (A.parametricEquation())([X])

#ax.plot_surface(X, Y, X*X - Y*Y, rstride=1, cstride=1, cmap = cm.viridis, antialiased=False, alpha = 0.5)
ax.contour(X, Y, AV.equations[0](X, Y), zdir='z', offset=0, levels = [0])
ax.contour(X, Y, AV.equations[1](X, Y), zdir='z', offset=0, levels = [0], colors = 'red')
#ax.contour(X, Y, X*X, zdir='z', offset=-2, levels = [0])
#ax.contour(X, Y, X*X - Y*Y, levels = [0])
ax.set_zlim(zmin = -2)
#AV.equations[0](X, Y) - AV.equations[1](X, Y)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from typing import Callable, Union

# include the path to the src. module
import sys
sys.path.append('../src')

from algebraic import VectorSpace, AffineSpace, AffineVariety, Monomial
from elements import Vector

f = Monomial({0, 1, 2}, [1, 3, 2], 1)

fig = plt.figure()
ax = plt.axes()

f.plot2d([-5, 5], [-5, 5])
